# %% [markdown]
# # Tabela de frequência

# %%
from collections import Counter

frutas = ['maçã', 'banana', 'maçã', 'laranja', 'banana', 'banana',
          'maçã', 'banana', 'laranja', 'maçã', 'banana', 'banana',
          'laranja', 'maçã', 'maçã', 'banana', 'banana', 'maçã',
          'laranja', 'banana']

freq_frutas = Counter(frutas)
print(freq_frutas)
# Out:
# Counter({'banana': 9, 'maçã': 7, 'laranja': 4})

# %%
pesos = [162, 168, 155, 170, 165, 162, 168, 160]
Counter(pesos)
# Out:
# Counter({162: 2, 168: 2, 155: 1, 170: 1, 165: 1, 160: 1})
