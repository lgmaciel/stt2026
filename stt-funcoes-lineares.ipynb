# %%
import pandas as pd

df = pd.read_csv("dados/linear.csv")

df.plot(
    kind="line", # Definimos o tipo de gráfico
    x="X", # Valores do eixo x
    y="Y", # Valores correspondentes de y
    color = "red"
    )
# Out:
# <Axes: xlabel='X'>

# %%
import pandas as pd

df = pd.read_csv("dados/linear.csv")

df.plot(
    kind="scatter",
    x="X",
    y="Y",
    color = "red"
    )
# Out:
# <Axes: xlabel='X', ylabel='Y'>
