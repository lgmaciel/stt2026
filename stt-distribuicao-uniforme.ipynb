# %%
import numpy as np
import pandas as pd

# %%
dfd6 = pd.DataFrame (data = [1,6,3,5,2,5,6,5,5,6,5,3,5,3,3,3,5,4,4,1,4,3,5,5,4,1,6,1,4,1,3,4,4,1,3,3,2,3,2,1,5,5,2,5,4,5]).hist(bins=10)

# %%
d1 = np.random.uniform(1,6,1000)
df = pd.DataFrame(data = d1, columns= ["D6"])
print(f"Média: {df.mean()}")
print(f"Desv. padrão: {df.std()}")
df.hist(bins=20)
# Out:
# Média: D6    3.489528
# dtype: float64
# Desv. padrão: D6    1.413861
# dtype: float64
# array([[<Axes: title={'center': 'D6'}>]], dtype=object)

# %%
d1 = np.random.uniform(1,6,1000)
d2 = np.random.uniform(1,4,1000)
n = d1 + d2

df_n = pd.DataFrame(data=n)
df_n.hist(bins=20)
print(f"Média: {df_n.mean()}")
print(f"Desv. padrão: {df_n.std()}")
# Out:
# Média: 0    6.049266
# dtype: float64
# Desv. padrão: 0    1.680173
# dtype: float64
